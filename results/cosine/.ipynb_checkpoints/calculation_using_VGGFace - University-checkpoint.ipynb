# %%
import pandas as pd
from deepface import DeepFace

# %%
df = pd.read_csv('../../dataset/Labeled Faces in the University Students Dataset/master.csv')
df.head()
# Out:
#       file_x     file_y Decision
# 0  img20.jpg  img21.jpg      Yes
# 1  img16.jpg  img17.jpg      Yes
# 2   img3.jpg  img12.jpg      Yes
# 3  img22.jpg  img23.jpg      Yes
# 4  img24.jpg  img25.jpg      Yes

# %%
df['file_x'] = '../../dataset/Labeled Faces in the University Students Dataset/' + df['file_x'].astype(str)
df['file_y'] = '../../dataset/Labeled Faces in the University Students Dataset/' + df['file_y'].astype(str)

# %%
instances = df[["file_x", "file_y"]].values.tolist()
instances
# Out:
# [['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img21.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img17.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img12.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img14.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img18.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img8.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img16.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img17.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img16.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img17.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img3.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img12.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img3.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img12.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img20.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img21.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img3.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img12.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img3.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img12.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img16.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img17.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img22.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img23.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img3.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img12.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img24.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img25.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img22.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img23.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img1.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img2.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img4.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img5.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img6.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img7.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img10.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img11.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img24.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img25.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img13.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img14.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img15.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img1.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img2.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img4.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img5.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img6.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img7.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img10.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img11.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img14.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img14.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img15.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img18.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img15.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img19.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img13.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img14.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img14.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img15.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img15.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img18.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img18.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img19.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img8.jpg'],
#  ['../../dataset/Labeled Faces in the Wild Dataset/img19.jpg',
#   '../../dataset/Labeled Faces in the Wild Dataset/img9.jpg']]

# %%
model_name = "VGG-Face"
distance_metric = "cosine"

# %%
resp_obj = DeepFace.verify(instances, model_name = model_name, distance_metric = distance_metric)
# Out:
# Verification: 100%|██████████| 300/300 [17:09<00:00,  3.43s/it]

# %%
distances = []
for i in range(0, len(instances)):
    distance = round(resp_obj["pair_%s" % (i+1)]["distance"], 4)
    distances.append(distance)

# %%
df["distance"] = distances
df.head()
# Out:
#                                               file_x  \
# 0  ../../dataset/Labeled Faces in the Wild Datase...
# 1  ../../dataset/Labeled Faces in the Wild Datase...
# 2  ../../dataset/Labeled Faces in the Wild Datase...
# 3  ../../dataset/Labeled Faces in the Wild Datase...
# 4  ../../dataset/Labeled Faces in the Wild Datase...
#
#                                               file_y Decision  distance
# 0  ../../dataset/Labeled Faces in the Wild Datase...      Yes    0.0772
# 1  ../../dataset/Labeled Faces in the Wild Datase...      Yes    0.2317
# 2  ../../dataset/Labeled Faces in the Wild Datase...      Yes    0.2811
# 3  ../../dataset/Labeled Faces in the Wild Datase...      Yes    0.2294
# 4  ../../dataset/Labeled Faces in the Wild Datase...      Yes    0.0811

# %%
#!pip3 install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.7.3-cp39-cp39-win_amd64.whl (34.3 MB)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in c:\users\munna\anaconda3\envs\deeplearning\lib\site-packages (from scipy) (1.20.3)
# Installing collected packages: scipy
# Successfully installed scipy-1.7.3

# %%
df[df.Decision == "Yes"].distance.plot.kde()
df[df.Decision == "No"].distance.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#!pip install chefboost
from chefboost import Chefboost as chef

# %%
config = {'algorithm': 'C4.5'}

# %%
tmp_df = df[['distance', 'Decision']].rename(columns = {"decision": "Decision"}).copy()
model = chef.fit(tmp_df, config)
# Out:
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# -------------------------
# finished in  0.5050013065338135  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  94.66666666666667 % on  300  instances
# Labels:  ['Yes' 'No']
# Confusion matrix:  [[22, 0], [16, 262]]
# Precision:  100.0 %, Recall:  57.8947 %, F1:  73.3333 %

# %%
threshold = 0.256 #comes from c4.5 algorithm

# %%
df["prediction"] = "No"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/4039155934.py in <module>
# ----> 1 df["prediction"] = "No"
#
# NameError: name 'df' is not defined

# %%
idx = df[df.distance <= threshold].index
df.loc[idx, 'prediction'] = 'Yes'

# %%
df.sample(5)
# Out:
#                                                 file_x  \
# 230  ../../dataset/Labeled Faces in the Wild Datase...
# 174  ../../dataset/Labeled Faces in the Wild Datase...
# 111  ../../dataset/Labeled Faces in the Wild Datase...
# 280  ../../dataset/Labeled Faces in the Wild Datase...
# 160  ../../dataset/Labeled Faces in the Wild Datase...
#
#                                                 file_y Decision  distance  \
# 230  ../../dataset/Labeled Faces in the Wild Datase...       No    0.6558
# 174  ../../dataset/Labeled Faces in the Wild Datase...       No    0.6643
# 111  ../../dataset/Labeled Faces in the Wild Datase...       No    0.7532
# 280  ../../dataset/Labeled Faces in the Wild Datase...       No    0.7131
# 160  ../../dataset/Labeled Faces in the Wild Datase...       No    0.5174
#
#     prediction
# 230          0
# 174          0
# 111          0
# 280          0
# 160          0

# %%
#!pip install scikit-learn

from sklearn.metrics import confusion_matrix,roc_curve,auc

# %%
cm = confusion_matrix(df.Decision.values, df.prediction.values)

# %%
tn, fp, fn, tp = cm.ravel()

# %%
tn, fp, fn, tp
# Out:
# (262, 0, 16, 22)

# %%
recall = tp / (tp + fn)
precision = tp / (tp + fp)
accuracy = (tp + tn)/(tn + fp +  fn + tp)
f1 = 2 * (precision * recall) / (precision + recall)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6944/1377600402.py in <module>
# ----> 1 recall = tp / (tp + fn)
#       2 precision = tp / (tp + fp)
#       3 accuracy = (tp + tn)/(tn + fp +  fn + tp)
#       4 f1 = 2 * (precision * recall) / (precision + recall)
#
# NameError: name 'tp' is not defined

# %%
print("Precision: ", 100*precision,"%")
print("Recall: ", 100*recall,"%")
print("F1 score ",100*f1, "%")
print("Accuracy: ", 100*accuracy,"%")
# Out:
# Precision:  100.0 %
# Recall:  57.89473684210527 %
# F1 score  73.33333333333334 %
# Accuracy:  94.66666666666667 %
